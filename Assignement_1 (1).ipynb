# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1: Fizz Buzz

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ![FizzBuzz.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# Reviewed a stack overflow post about the methods of using the modulus operator https://stackoverflow.com/questions/17524673/understanding-the-modulus-operator through the use of this I wrote some logic utilizing the modulus operator to check if certain numbers were divisable by others

# %%
# Your draft code here (does not need to be fully correct)
def FizzBuzz(n: int) -> list[str]:
    answer = []
    for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
            answer.append("FizzBuzz")
        elif i % 5 == 0:
            answer.append("Buzz")
        elif i % 3 == 0:
            answer.append("Fizz")
    return answer

FizzBuzz(25)
# Out:
# ['Fizz',
#  'Buzz',
#  'Fizz',
#  'Fizz',
#  'Buzz',
#  'Fizz',
#  'FizzBuzz',
#  'Fizz',
#  'Buzz',
#  'Fizz',
#  'Fizz',
#  'Buzz']

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
def FizzBuzz(n: int) -> list[str]:
    answer = []
    for i in range(1, n + 1):
        if i % 15 == 0:
            answer.append("FizzBuzz")
        elif i % 5 == 0:
            answer.append("Buzz")
        elif i % 3 == 0:
            answer.append("Fizz")
        else:
            answer.append(str(i))
    return answer
FizzBuzz(17)
# Out:
# ['1',
#  '2',
#  'Fizz',
#  '4',
#  'Buzz',
#  'Fizz',
#  '7',
#  '8',
#  'Fizz',
#  'Buzz',
#  '11',
#  'Fizz',
#  '13',
#  '14',
#  'FizzBuzz',
#  '16',
#  '17']

# %% [markdown]
# ![Screenshot 2025-09-20 222311.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Added an else statement to handle appending the none divisable values

# Draft version Doesnt append none divisable values
def FizzBuzz(n: int) -> list[str]:
    answer = []
    for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
            answer.append("FizzBuzz")
        elif i % 5 == 0:
            answer.append("Buzz")
        elif i % 3 == 0:
            answer.append("Fizz")
    return answer


# Fixed version Appends none diviable values
def FizzBuzz(n: int) -> list[str]:
    answer = []
    for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
            answer.append("FizzBuzz")
        elif i % 5 == 0:
            answer.append("Buzz")
        elif i % 3 == 0:
            answer.append("Fizz")
        else:
            answer.append(str(i))
    return answer

# %%
# Fix 2: Simplified and cleaned up logic to determine if "FizzBuzz" should be appended

# Draft version: checks when divided by both 3 and 5 it has a remainder equal to 0
def FizzBuzz(n: int) -> list[str]:
    answer = []
    for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
            answer.append("FizzBuzz")
        elif i % 5 == 0:
            answer.append("Buzz")
        elif i % 3 == 0:
            answer.append("Fizz")
        else:
            answer.append(str(i))
    return answer
# Fixed version: combines 3 and 5 so that only when divided by 15 the remainder needs to equal 0
def FizzBuzz(n: int) -> list[str]:
    answer = []
    for i in range(1, n + 1):
        if i % 15 == 0:
            answer.append("FizzBuzz")
        elif i % 5 == 0:
            answer.append("Buzz")
        elif i % 3 == 0:
            answer.append("Fizz")
        else:
            answer.append(str(i))
    return answer

# %% [markdown]
# ## 5. Reflection on Your Contribution
#
# As the code is my own, my main contributions were through debugging my own mistakes such as when I didnt add an else statement to append the value of i as a string to the list when all other cases were false. The only other contribution I made to improve my code was to simplify the logic regarding the case where the integer must be divisable by 3 and 5.

# %% [markdown]
# #  Problem 2: Palindrome Number

# %% [markdown]
# ## 1. Understanding & Breakdown
# ![Palindrome_Number.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# I learned I could reverse a string using slicing from https://stackoverflow.com/questions/509211/how-slicing-in-python-works Using this idea I tried writing a function that would reverse the string value of x

# %%
# Your draft code here (does not need to be fully correct)
def isPalindrome(self, x: int) -> bool:
 reversed_string = str(x)[::-1]
 if str(x) == reversed_string:
  return True
 else:
  return False

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
def isPalindrome(x: int) -> bool:
     return str(x) == str(x)[::-1]

isPalindrome(437856783)
# Out:
# False

# %% [markdown]
# ![Screenshot 2025-09-20 222343.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Removed unnecessary reversed string variable

# Draft version
def isPalindrome(self, x: int) -> bool:
 reversed_string = str(x)[::-1]
 if str(x) == reversed_string:
  return True
 else:
  return False

# Fixed version (cleaner and scalable)
def isPalindrome(self, x: int) -> bool:
 if str(x) == str(x)[::-1]:
  return True
 else:
  return False

# %%
# Fix 2: Simplified logic by removing unneeded if statements

# Draft version: unneeded if statements
def isPalindrome(self, x: int) -> bool:
 if str(x) == str(x)[::-1]: #unneeded as a return statement with this logic will yield a bool value
  return True
 else:
  return False

# Fixed version: simplified one line return statement
def isPalindrome(x: int) -> bool:
     return str(x) == str(x)[::-1]

# %% [markdown]
# ## 5. Reflection on Your Contribution
#
# My main contribution was probably the simplification of the logic down to a single return line of code, as many other solutions on leetcode seemed to leave unecessary long logic in order to obtain the same result.

# %% [markdown]
# #  Problem 3: Reversed Integer

# %% [markdown]
# ## 1. Understanding & Breakdown
# ![ReversedInteger.drawio.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# Reviewed leetcode solutions, helping to better grasp the logic behind and solidify my logic around getting the remainder of an integer to use as the first number in the reversed integer. Furthermore how to continue reutilizing this logic to get the whole reversed number. I practiced this logic with the following function.

# %%
def reverse(x: int) -> int:
        x = abs(x)
        reversed_int = 0
        while x != 0:
            remainder = x % 10
            x //= 10
            reversed_int = reversed_int + remainder
        print(reversed_int)
reverse(789)
# Out:
# 24

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
def reverse(x: int) -> int:
        MAX_INT = 2**31 - 1
        MIN_INT = -2**31
        sign = 1
        if x < 0:
            sign = -1
        x = abs(x)
        reversed_int = 0
        while x != 0:
            remainder = x % 10
            x //= 10
            reversed_int = reversed_int * 10 + remainder

        return (reversed_int * sign) if MIN_INT <= reversed_int <= MAX_INT else 0

reverse(-7846)
# Out:
# -6487

# %% [markdown]
# ![Screenshot 2025-09-20 222137.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Fixed logic when combining the remainders to create the reversed integer

# Draft version: remainders were only added together resulting in a sum rather than the reversed integer
def reverse(x: int) -> int:
        x = abs(x)
        reversed_int = 0
        while x != 0:
            remainder = x % 10
            x //= 10
            reversed_int = reversed_int + remainder
        print(reversed_int)

# Fixed version: added a multiplication of 10 shifting the tens place by one everytime a remainder is added
def reverse(x: int) -> int:
       x = abs(x)
       reversed_int = 0
       while x != 0:
            remainder = x % 10
            x //= 10
            reversed_int = reversed_int * 10 + remainder
       print(reversed_int)

# %%
# Fix 2: Added a sign variable along with logic to handle negative integers

# Draft version: negative integers result in positive integers being returned
def reverse(x: int) -> int:
       x = abs(x)
       reversed_int = 0
       while x != 0:
            remainder = x % 10
            x //= 10
            reversed_int = reversed_int * 10 + remainder
       print(reversed_int)
# Fixed version: adds a sign variable and multiplies final reversed integer by it
def reverse(x: int) -> int:
        if x < 0: #checks if x value is less than 0 and sets sign to -1
            sign = -1
        x = abs(x)
        reversed_int = 0
        while x != 0:
            remainder = x % 10
            x //= 10
            reversed_int = reversed_int * 10 + remainder

        if sign == -1: #if the number was negative multiplies final reversed integer by the sign
            reversed_int = reversed_int * sign

        print(reversed_int)

# %% [markdown]
# ## 5. Reflection on Your Contribution
#
# When it came to the mathematical logic in getting the individual values of the reversed integer while the code I refrenced untilised the logic properly. I failed to account for how to take the remainder and properly reconstruct the those values into a reverse integer resulting in me having to debug and work through the logic more throughly to determine that I needed to multiply the reversed integer by 10 before adding the recently determined remainder.
#
# Since I didnt utilise any further resources outside of the orginal mathematical logic again I was left with the issue of the negetive numbers coming out positive and therfore had to implement new logic in order to circumvent that issue.

# %% [markdown]
# #  Problem 4: Two Sum

# %% [markdown]
# ## 1. Understanding & Breakdown
# ![TwoSum.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# Reviewed one stack overflow post related to related to iterating based on the index value of a list rather than the value at said index https://stackoverflow.com/questions/522563/how-can-i-access-the-index-value-in-a-for-loop With this I practiced writing a function to iterate in this fashion

# %%
def twoSum( nums: list[int], target: int) -> list[int]:
        for i in range(len(nums)):
            second_number = target - nums[i]
            print(second_number)
            print(nums[i])
            if nums[i] + second_number == target:
                print(nums[i] + second_number)
                return nums[i] + second_number
            return []

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
def twoSum( nums: list[int], target: int) -> list[int]:
        required_nums = {}
        for i, num in enumerate(nums):
            second_number = target - num

            if num + second_number == target and second_number in required_nums:
                return [required_nums[second_number], i]

            required_nums[num] = i
twoSum([5,7,9,10,25], 19)
# Out:
# [2, 3]

# %% [markdown]
# ![Screenshot 2025-09-20 222240.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Implemented the new itering of the for loop to resolve the out of index range issue

# Draft version Resulted in a error due to i being out of the index range
def twoSum( nums: list[int], target: int) -> list[int]:
        for i in nums:
            second_number = nums[i] - target
            if nums[i] + second_number == target:
                return nums[i] + second_number


# Fixed version Changed how the for loop interated so that i would remain within the index range
def twoSum( nums: list[int], target: int) -> list[int]:
        for i in range(len(nums)):
            second_number = target - nums[i]
            print(second_number)
            print(nums[i])
            if nums[i] + second_number == target:
                print(nums[i] + second_number)
                return nums[i] + second_number
            return []

# %%
# Fix 2: refined logic and Added a dictionary to prevent the second number not being a match if the required matching value in the list was at a further index number

# Draft version: i.e if the target is 19 and 9 is before 10 in the list the second_number value will never find its match as the loop will iterate past it
def twoSum( nums: list[int], target: int) -> list[int]:
        for i in range(len(nums)):
            second_number = target - nums[i]

            if nums[i] + second_number == target: #Logic prevents a match between the second_number and previous nums vlaues
                return nums[i] + second_number
            return []

# Fixed version: Fixes logic by adding a new dictionary which keeps past of past iterated values so that a match with previous values can be made
def twoSum( nums: list[int], target: int) -> list[int]:
        required_nums = {}
        for i, num in enumerate(nums): #added enumeration so that both the index number and value can be iterated on
            second_number = target - num

            if num + second_number == target and second_number in required_nums: #Checdks if the second_number is in the new dictionary resolving the error
                return [required_nums[second_number], i]

            required_nums[num] = i
# Out:
# []

# %% [markdown]
# ## 5. Reflection on Your Contribution
#
# When I utilised the stack overflow post about the enumerate() function and refrenced it for my own code I failed to completely grasp how the function operated before implementing it resulting in me using overlaping variable names. In this case I used nums as the second item of interation in the for loop causing some errors to arise in the code but I eventually found the root cause and altered the name of the second item.

# %% [markdown]
# #  Problem 5: Valid Palindrome

# %% [markdown]
# ## 1. Understanding & Breakdown
# ![Valid_Palindrome.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# Reviewed a stack overflow post for both lower casing a string https://stackoverflow.com/questions/6797984/how-do-i-lowercase-a-string-in-python as well as a post regarding how to check if a string character is only in the alphabet https://stackoverflow.com/questions/18667410/how-to-check-if-a-string-only-contains-letters

# %%
def isPalindrome(s: str) -> bool:
        cleaned_string = ""
        for char in s:
            if 'a' <= char <= 'z':
                cleaned_string += char
            elif 'A' <= char <= 'Z':
                cleaned_string += char.lower()

        print(cleaned_string)
        print(cleaned_string[::-1])
        return cleaned_string == cleaned_string[::-1]
isPalindrome("once Upon A TiMe!")
# Out:
# onceuponatime
# emitanopuecno
# False

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
def isPalindrome(s: str) -> bool:
        cleaned_string = ""
        for char in s:
            if char.isalpha():
                cleaned_string += char.lower()

        return cleaned_string == cleaned_string[::-1]
isPalindrome("racE caR!")
# Out:
# True

# %% [markdown]
# ![Screenshot 2025-09-20 222221.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Added the lower() function to prevent capital letters from being added to the cleaned string

# Draft version: capital letters get added to the cleaned_string
def isPalindrome(s: str) -> bool:
        cleaned_string = ""
        for char in s:
            if 'a' <= char <= 'z':
                cleaned_string += char
            elif 'A' <= char <= 'Z':
                cleaned_string += char

        return cleaned_string == cleaned_string[::-1]

# Fixed version: makes any capital letters lowercase
def isPalindrome(s: str) -> bool:
        cleaned_string = ""
        for char in s:
            if 'a' <= char <= 'z':
                cleaned_string += char
            elif 'A' <= char <= 'Z':
                cleaned_string += char.lower()

        return cleaned_string == cleaned_string[::-1]

# %%
# Fix 2: Cleans up the logic by utilizing the isalpha() function

# Draft version: requires multiple if statements to determine if the char is within the alphabet
def isPalindrome(s: str) -> bool:
        cleaned_string = ""
        for char in s:
            if 'a' <= char <= 'z':
                cleaned_string += char
            elif 'A' <= char <= 'Z':
                cleaned_string += char.lower()

        return cleaned_string == cleaned_string[::-1]
# Fixed version: only requires one if statement through the implementation of isalpha
def isPalindrome(s: str) -> bool:
        cleaned_string = ""
        for char in s:
            if char.isalpha():
                cleaned_string += char.lower()

        return cleaned_string == cleaned_string[::-1]

# %% [markdown]
# ## 5. Reflection on Your Contribution
#
# As all of the code was my own, again the main contributions of me fall to the simplification of the logic using functions built into python instead of constructing them myself. This along side me fixing issues with my original draft code which didnt output a purely lower case string which resulted in the incorect bool value to be outputed.
